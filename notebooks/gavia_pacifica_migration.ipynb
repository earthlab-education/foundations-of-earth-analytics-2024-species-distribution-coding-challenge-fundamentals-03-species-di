# %% [markdown]
# # Examining Migration of the Pacific Loon (Gavia pacifica) in 2023 using data from the Global Biodiversity Information Facility (GBIF)
#
# Some narrative here. A couple cites.

# %%
# %store -r

import os
import pathlib
import time
import calendar 
import zipfile
from getpass import getpass
from glob import glob

import geopandas as gpd
import pandas as pd
import pygbif.occurrences as occ
import pygbif.species as species

#dynamic mapping
import hvplot.pandas
import cartopy.crs as ccrs
import panel as pn
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e2dbbc45-222c-4cdd-8a1e-99b3186b6a71" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"fcd37b85-675d-4229-a031-dd47e38b7a20":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"dde9fe7e534543f9afd2be504feed4a8","client_comm_id":"510da4f6ee8c41e1be3f1376d3838a31"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"fcd37b85-675d-4229-a031-dd47e38b7a20","roots":{"p1002":"e2dbbc45-222c-4cdd-8a1e-99b3186b6a71"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#Get the ecoregions shapefile
ecoreg_shp_dir = os.path.join(
    # Home directory
    pathlib.Path.home(),
    # Earth analytics data directory
    'earth-analytics',
    'data',
    # Project directory
    'species_dist_coding_assign',
    'ecoregions_dirname'
)
os.makedirs(ecoreg_shp_dir, exist_ok=True)
ecoregion_shppath = os.path.join(ecoreg_shp_dir, 'ecoregions_filename.shp')
# Open up the ecoregions boundaries
ecoreg_gdf = gpd.read_file(ecoregion_shppath)

# Name the index so it will match the other data later on
ecoreg_gdf.index.name = 'ecoregion'
#ecoreg_gdf.crs

# %%
ecoreg_gdf
# Out:
#            OBJECTID                                           ECO_NAME  \
# ecoregion
# 0               1.0                                 Adelie Land tundra
# 1               2.0             Admiralty Islands lowland rain forests
# 2               3.0  Aegean and Western Turkey sclerophyllous and m...
# 3               4.0                       Afghan Mountains semi-desert
# 4               5.0                   Ahklun and Kilbuck Upland Tundra
# ...             ...                                                ...
# 842           848.0                      Sulawesi lowland rain forests
# 843           212.0                       East African montane forests
# 844           224.0                                Eastern Arc forests
# 845            79.0                        Borneo montane rain forests
# 846           376.0                    Kinabalu montane alpine meadows
#
#            BIOME_NUM                                      BIOME_NAME  \
# ecoregion
# 0               11.0                                          Tundra
# 1                1.0  Tropical & Subtropical Moist Broadleaf Forests
# 2               12.0        Mediterranean Forests, Woodlands & Scrub
# 3               13.0                      Deserts & Xeric Shrublands
# 4               11.0                                          Tundra
# ...              ...                                             ...
# 842              1.0  Tropical & Subtropical Moist Broadleaf Forests
# 843              1.0  Tropical & Subtropical Moist Broadleaf Forests
# 844              1.0  Tropical & Subtropical Moist Broadleaf Forests
# 845              1.0  Tropical & Subtropical Moist Broadleaf Forests
# 846             10.0                 Montane Grasslands & Shrublands
#
#                  REALM ECO_BIOME_  NNH  ECO_ID  SHAPE_LENG  SHAPE_AREA  \
# ecoregion
# 0           Antarctica       AN11    1     117    9.749780    0.038948
# 1          Australasia       AU01    2     135    4.800349    0.170599
# 2           Palearctic       PA12    4     785  162.523044   13.844952
# 3           Palearctic       PA13    4     807   15.084037    1.355536
# 4             Nearctic       NE11    1     404   22.590087    8.196573
# ...                ...        ...  ...     ...         ...         ...
# 842        Australasia       AU01    2     156  150.744361    9.422097
# 843         Afrotropic       AF01    3       8  157.848926    5.010930
# 844         Afrotropic       AF01    3       9   34.153333    0.890325
# 845        Indomalayan       IN01    2     220   38.280990    9.358407
# 846        Indomalayan       IN10    3     313    5.722539    0.352694
#
#                                     NNH_NAME    COLOR COLOR_BIO COLOR_NNH  \
# ecoregion
# 0                             Half Protected  #63CFAB   #9ED7C2   #257339
# 1          Nature Could Reach Half Protected  #70A800   #38A700   #7BC141
# 2                           Nature Imperiled  #FF7F7C   #FE0000   #EE1E23
# 3                           Nature Imperiled  #FA774D   #CC6767   #EE1E23
# 4                             Half Protected  #4C82B6   #9ED7C2   #257339
# ...                                      ...      ...       ...       ...
# 842        Nature Could Reach Half Protected  #70A800   #38A700   #7BC141
# 843                     Nature Could Recover  #13ED00   #38A700   #F9A91B
# 844                     Nature Could Recover  #267400   #38A700   #F9A91B
# 845        Nature Could Reach Half Protected  #23DB01   #38A700   #7BC141
# 846                     Nature Could Recover  #C48832   #D6C39D   #F9A91B
#
#              LICENSE                                           geometry
# ecoregion
# 0          CC-BY 4.0  MULTIPOLYGON (((158.7141 -69.60657, 158.71264 ...
# 1          CC-BY 4.0  MULTIPOLYGON (((147.28819 -2.57589, 147.2715 -...
# 2          CC-BY 4.0  MULTIPOLYGON (((26.88659 35.32161, 26.88297 35...
# 3          CC-BY 4.0  MULTIPOLYGON (((65.48655 34.71401, 65.52872 34...
# 4          CC-BY 4.0  MULTIPOLYGON (((-160.26404 58.64097, -160.2673...
# ...              ...                                                ...
# 842        CC-BY 4.0  MULTIPOLYGON (((117.33111 -7.53306, 117.30525 ...
# 843        CC-BY 4.0  MULTIPOLYGON (((36.7375 -3.13, 36.7375 -3.1316...
# 844        CC-BY 4.0  MULTIPOLYGON (((36.38 -8.96583, 36.38 -8.96667...
# 845        CC-BY 4.0  MULTIPOLYGON (((112.82394 -0.5066, 112.82298 -...
# 846        CC-BY 4.0  MULTIPOLYGON (((116.52616 6.11011, 116.52734 6...
#
# [847 rows x 16 columns]

# %%
# Simplify the geometry to speed up processing
ecoreg_gdf.geometry = ecoreg_gdf.simplify(.1, preserve_topology=False)
# Change the CRS to Mercator for mapping
ecoreg_gdf = ecoreg_gdf.to_crs(ccrs.Mercator())
# Check that the plot runs in a reasonable amount of time
#ecoreg_gdf.hvplot(geo=True, crs=ccrs.Mercator())

# %%
#convert the pacific loon occurrence data to a geodataframe
gaviapac_gbif_gdf = (
    gpd.GeoDataFrame(
        gaviapac_gbif_df, 
        geometry=gpd.points_from_xy(
            gaviapac_gbif_df.decimalLongitude, 
            gaviapac_gbif_df.decimalLatitude), 
        crs="EPSG:4326")
    # Select the desired columns
    #[['gbifID', 'decimalLatitude', 'decimalLongitude', 'month']]
)
gaviapac_gbif_gdf = gaviapac_gbif_gdf.to_crs(ccrs.Mercator())
gaviapac_gbif_gdf
# Out:
#                                                  occurrenceID         species  \
# gbifID
# 4953151418  https://www.inaturalist.org/observations/17616...  Gavia pacifica
# 4950273871  https://www.inaturalist.org/observations/24385...  Gavia pacifica
# 4946632056  https://www.inaturalist.org/observations/23034...  Gavia pacifica
# 4937187752  https://www.inaturalist.org/observations/14980...  Gavia pacifica
# 4936192321  https://www.inaturalist.org/observations/19074...  Gavia pacifica
# ...                                                       ...             ...
# 4018248179  https://www.inaturalist.org/observations/14657...  Gavia pacifica
# 4018104911  https://www.inaturalist.org/observations/14636...  Gavia pacifica
# 4015258054  https://www.inaturalist.org/observations/14594...  Gavia pacifica
# 4011669284  https://www.inaturalist.org/observations/14571...  Gavia pacifica
# 4011620272  https://www.inaturalist.org/observations/14567...  Gavia pacifica
#
#                              scientificName countryCode occurrenceStatus  \
# gbifID
# 4953151418  Gavia pacifica (Lawrence, 1858)          CA          PRESENT
# 4950273871  Gavia pacifica (Lawrence, 1858)          US          PRESENT
# 4946632056  Gavia pacifica (Lawrence, 1858)          US          PRESENT
# 4937187752  Gavia pacifica (Lawrence, 1858)          US          PRESENT
# 4936192321  Gavia pacifica (Lawrence, 1858)          US          PRESENT
# ...                                     ...         ...              ...
# 4018248179  Gavia pacifica (Lawrence, 1858)          CA          PRESENT
# 4018104911  Gavia pacifica (Lawrence, 1858)          US          PRESENT
# 4015258054  Gavia pacifica (Lawrence, 1858)          US          PRESENT
# 4011669284  Gavia pacifica (Lawrence, 1858)          US          PRESENT
# 4011620272  Gavia pacifica (Lawrence, 1858)          US          PRESENT
#
#             individualCount  decimalLatitude  decimalLongitude  month  year  \
# gbifID
# 4953151418              NaN        58.765791        -94.122485      8  2023
# 4950273871              NaN        32.758759       -117.245769     11  2023
# 4946632056              NaN        36.909267       -122.026831     11  2023
# 4937187752              NaN        49.000610       -123.167541      2  2023
# 4936192321              NaN        34.725271       -118.167093     11  2023
# ...                     ...              ...               ...    ...   ...
# 4018248179              NaN        48.315404       -123.650051      1  2023
# 4018104911              NaN        36.959997       -122.018938      1  2023
# 4015258054              NaN        57.082025       -135.379996      1  2023
# 4011669284              NaN        39.517589        -83.990892      1  2023
# 4011620272              NaN        39.517610        -83.990910      1  2023
#
#             speciesKey      basisOfRecord                           geometry
# gbifID
# 4953151418     2481955  HUMAN_OBSERVATION   POINT (-10477667.102 8093368.02)
# 4950273871     2481955  HUMAN_OBSERVATION  POINT (-13051739.303 3840207.905)
# 4946632056     2481955  HUMAN_OBSERVATION   POINT (-13583964.69 4400804.577)
# 4937187752     2481955  HUMAN_OBSERVATION  POINT (-13710947.946 6242699.205)
# 4936192321     2481955  HUMAN_OBSERVATION  POINT (-13154300.621 4102268.936)
# ...                ...                ...                                ...
# 4018248179     2481955  HUMAN_OBSERVATION  POINT (-13764660.714 6127561.023)
# 4018104911     2481955  HUMAN_OBSERVATION  POINT (-13583086.045 4407839.324)
# 4015258054     2481955  HUMAN_OBSERVATION  POINT (-15070432.218 7741003.326)
# 4011669284     2481955  HUMAN_OBSERVATION   POINT (-9349823.329 4768891.522)
# 4011620272     2481955  HUMAN_OBSERVATION    POINT (-9349825.332 4768894.54)
#
# [33715 rows x 13 columns]

# %%
gaviapac_gbif_gdf.crs
# Out:
# <Projected CRS: +proj=merc +ellps=WGS84 +lon_0=0.0 +x_0=0.0 +y_0=0 ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Mercator (variant A)
# Datum: Unknown based on WGS 84 ellipsoid
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gaviapac_ecoregion_gdf = (
    ecoreg_gdf
    # Match the CRS of the GBIF data and the ecoregions
    .to_crs(gaviapac_gbif_gdf.crs)
    # Find ecoregion for each observation
    .sjoin(
        gaviapac_gbif_gdf,
        how='inner', 
        predicate='contains')
    # Select the required columns
    [['OBJECTID', 'gbifID', 'ECO_NAME','BIOME_NUM','BIOME_NAME', 'month', 'SHAPE_AREA']]
)
#gaviapac_ecoregion_gdf

# %%
# Aggregate the occurrences to ecoregion and month
gaviapac_occ_df = (
    gbif_ecoregion_gdf
    #.reset index()
    # For each ecoregion, for each month...
    .groupby(['ecoregion', 'month'])
    # ...count the number of occurrences
    .agg(occurrences=('gbifID', 'count'),
         area=('SHAPE_AREA', 'first'))
)
# Get rid of rare observations (possible misidentification?)
gaviapac_occ_df = occurrence_df[occurrence_df.occurrences > 1]

#Normalize by area
gaviapac_occ_df['density'] = (
    gaviapac_occ_df.occurrences / gaviapac_occ_df.area
)

#gaviapac_occ_df

# %%
#check the monthly data values across all ecoregions
# gaviapac_occ_df.groupby('month').mean()

# %%
#check the data given plotting issues
# #ecoregion_mean = gaviapac_occ_df.groupby('ecoregion').mean()
#ecoregion_mean
#ecoregion_mean.to_csv('ecoregion_means.csv')
#gaviapac_occ_df.to_csv('gaviapacifica_occur_df.csv')

# %%
#gaviapac_occ_df.crs
gaviapac_ecoreg_gdf = ecoreg_gdf.join(gaviapac_occ_df)

# %%
# setup slider widget to be labeled as the month name
mon_widget = pn.widgets.DiscreteSlider(
            options={calendar.month_name[month_num]: month_num 
                     for month_num in range(1,13) }
        )
#mon_widget

# %%
# Get the plot bounds so they don't change with the slider
xmin, ymin, xmax, ymax = gaviapac_ecoreg_gdf.to_crs(ccrs.Mercator()).total_bounds

# Plot occurrence by ecoregion and month
gaviapac_migration_plot = (
    gaviapac_ecoreg_gdf
    .hvplot(
        c='norm_occurrences',
        groupby='month',
        # Use background tiles
        geo=True, crs=ccrs.Mercator(), tiles='CartoLight',
        title="Pacific Loon (Gavia pacifica) Migration Across Ecoregions in 2023",
        xlim=(xmin, xmax), ylim=(ymin, ymax),
        frame_height=600,
        widgets = {'month': mon_widget},
        widget_location='bottom'
    )
)

# Save the plot
gaviapac_migration_plot.save('gaviapac_migration_plot_migration.html', 
                                            embed=True)

# Show the plot
gaviapac_migration_plot
# Out:
# /opt/conda/lib/python3.11/site-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# WARNING:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1066', ...)
# BokehModel(combine_events=True, render_bundle={'docs_json': {'11615e4d-000b-4e26-9a14-cbfecfef5155': {'version…
# 2024-11-07 20:36:49,345 ERROR: panel.reactive - Callback failed for object named '' changing property {'value': 10}
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py", line 2222, in _update_glyphs
#     self._update_glyph(renderer, properties, mapping, glyph, source, data)
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py", line 1992, in _update_glyph
#     glyph.update(**update)
#   File "/opt/conda/lib/python3.11/site-packages/bokeh/core/has_props.py", line 483, in update
#     setattr(self, k, v)
#   File "/opt/conda/lib/python3.11/site-packages/bokeh/core/has_props.py", line 336, in __setattr__
#     return super().__setattr__(name, value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/bokeh/core/property/descriptors.py", line 330, in __set__
#     value = self.property.prepare_value(obj, self.name, value)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/bokeh/core/property/dataspec.py", line 599, in prepare_value
#     return super().prepare_value(cls, name, value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/bokeh/core/property/bases.py", line 363, in prepare_value
#     raise ValueError(f"failed to validate {obj_repr}.{name}: {error}")
# ValueError: failed to validate MultiPolygons(id='p1110', ...).fill_color: expected an element of either String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)) or Struct(expr=Instance(Expression), transform=Instance(Transform)), got dim('norm_occurrences')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/panel/reactive.py", line 462, in _process_events
#     self.param.update(**self_params)
#   File "/opt/conda/lib/python3.11/site-packages/param/parameterized.py", line 2319, in update
#     restore = dict(self_._update(arg, **kwargs))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/param/parameterized.py", line 2352, in _update
#     self_._batch_call_watchers()
#   File "/opt/conda/lib/python3.11/site-packages/param/parameterized.py", line 2546, in _batch_call_watchers
#     self_._execute_watcher(watcher, events)
#   File "/opt/conda/lib/python3.11/site-packages/param/parameterized.py", line 2506, in _execute_watcher
#     watcher.fn(*args, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/panel/widgets/slider.py", line 509, in _sync_value
#     setattr(self, event.name, self.values[event.new])
#   File "/opt/conda/lib/python3.11/site-packages/param/parameterized.py", line 528, in _f
#     instance_param.__set__(obj, val)
#   File "/opt/conda/lib/python3.11/site-packages/param/parameterized.py", line 530, in _f
#     return f(self, obj, val)
#            ^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/param/parameterized.py", line 1553, in __set__
#     obj.param._call_watcher(watcher, event)
#   File "/opt/conda/lib/python3.11/site-packages/param/parameterized.py", line 2526, in _call_watcher
#     self_._execute_watcher(watcher, (event,))
#   File "/opt/conda/lib/python3.11/site-packages/param/parameterized.py", line 2506, in _execute_watcher
#     watcher.fn(*args, **kwargs)
#   File "/opt/conda/lib/python3.11/site-packages/panel/pane/holoviews.py", line 350, in _widget_callback
#     self._update_plot(plot, pane)
#   File "/opt/conda/lib/python3.11/site-packages/panel/pane/holoviews.py", line 332, in _update_plot
#     plot.update(key)
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/plotting/plot.py", line 957, in update
#     item = self.__getitem__(key)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/plotting/plot.py", line 444, in __getitem__
#     self.update_frame(frame)
#   File "/opt/conda/lib/python3.11/site-packages/geoviews/plotting/bokeh/plot.py", line 128, in update_frame
#     super().update_frame(key, ranges=ranges, element=element)
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/util.py", line 868, in wrapper
#     return f(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py", line 3462, in update_frame
#     subplot.update_frame(key, ranges, element=el)
#   File "/opt/conda/lib/python3.11/site-packages/geoviews/plotting/bokeh/plot.py", line 128, in update_frame
#     super().update_frame(key, ranges=ranges, element=element)
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/util.py", line 868, in wrapper
#     return f(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py", line 2306, in update_frame
#     self._update_glyphs(element, ranges, self.style[self.cyclic_index])
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py", line 2221, in _update_glyphs
#     with abbreviated_exception():
#   File "/opt/conda/lib/python3.11/site-packages/holoviews/core/options.py", line 222, in __exit__
#     raise AbbreviatedException(etype, value, traceback)
# holoviews.core.options.AbbreviatedException: ValueError: failed to validate MultiPolygons(id='p1110', ...).fill_color: expected an element of either String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)) or Struct(expr=Instance(Expression), transform=Instance(Transform)), got dim('norm_occurrences')
#
# To view the original traceback, catch this exception and call print_traceback() method.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py:2222, in ElementPlot._update_glyphs(self, element, ranges, style)
#    2221     with abbreviated_exception():
# -> 2222         self._update_glyph(renderer, properties, mapping, glyph, source, data)
#    2223 elif not self.static_source:
#
# File /opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py:1992, in ElementPlot._update_glyph(self, renderer, properties, mapping, glyph, source, data)
#    1991 for glyph, update in glyph_updates:
# -> 1992     glyph.update(**update)
#    1994 if data is not None and cds_replace and not self.static_source:
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/core/has_props.py:483, in HasProps.update(self, **kwargs)
#     482 for k, v in kwargs.items():
# --> 483     setattr(self, k, v)
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/core/has_props.py:336, in HasProps.__setattr__(self, name, value)
#     335 if name in properties:
# --> 336     return super().__setattr__(name, value)
#     338 descriptor = getattr(self.__class__, name, None)
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/core/property/descriptors.py:330, in PropertyDescriptor.__set__(self, obj, value, setter)
#     328     raise RuntimeError(f"{class_name}.{self.name} is a readonly property")
# --> 330 value = self.property.prepare_value(obj, self.name, value)
#     331 old = self._get(obj)
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/core/property/dataspec.py:599, in ColorSpec.prepare_value(self, cls, name, value)
#     598     value = tuple(int(v) if i < 3 else v for i, v in enumerate(value))
# --> 599 return super().prepare_value(cls, name, value)
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/core/property/bases.py:363, in Property.prepare_value(self, owner, name, value, hint)
#     362     obj_repr = owner if isinstance(owner, HasProps) else owner.__name__
# --> 363     raise ValueError(f"failed to validate {obj_repr}.{name}: {error}")
#     365 if isinstance(owner, HasProps):
#
# ValueError: failed to validate MultiPolygons(id='p1110', ...).fill_color: expected an element of either String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)) or Struct(expr=Instance(Expression), transform=Instance(Transform)), got dim('norm_occurrences')
#
# During handling of the above exception, another exception occurred:
#
# AbbreviatedException                      Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/jupyter_bokeh/widgets.py:149, in BokehModel._sync_model(self, _model, content, _buffers)
#     147 new = descriptor.property.prepare_value(model, descriptor.name, new)
#     148 old = descriptor._get(model)
# --> 149 descriptor._set(model, old, new, setter=setter)
#     151 for cb in model._callbacks.get(attr, []):
#     152     cb(attr, old, new)
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/core/property/descriptors.py:620, in PropertyDescriptor._set(self, obj, old, value, hint, setter)
#     617     self._set_value(obj, value)
#     619 # for notification purposes, "old" should be the logical old
# --> 620 self._trigger(obj, old, value, hint=hint, setter=setter)
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/core/property/descriptors.py:698, in PropertyDescriptor._trigger(self, obj, old, value, hint, setter)
#     661 """ Unconditionally send a change event notification for the property.
#     662
#     663 Args:
#    (...)
#     695
#     696 """
#     697 if hasattr(obj, 'trigger'):
# --> 698     obj.trigger(self.name, old, value, hint, setter)
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/model/model.py:571, in Model.trigger(self, attr, old, new, hint, setter)
#     569 # chain up to invoke callbacks
#     570 descriptor = self.lookup(attr)
# --> 571 super().trigger(descriptor.name, old, new, hint=hint, setter=setter)
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/util/callback_manager.py:186, in PropertyCallbackManager.trigger(self, attr, old, new, hint, setter)
#     184 if self.document is not None:
#     185     from ..model import Model
# --> 186     self.document.callbacks.notify_change(cast(Model, self), attr, old, new, hint, setter, invoke)
#     187 else:
#     188     invoke()
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/document/callbacks.py:251, in DocumentCallbackManager.notify_change(self, model, attr, old, new, hint, setter, callback_invoker)
#     247         hint.setter = setter
#     249     event = hint
# --> 251 self.trigger_on_change(event)
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/document/callbacks.py:418, in DocumentCallbackManager.trigger_on_change(self, event)
#     415     return
#     417 if event.callback_invoker is not None:
# --> 418     invoke_with_curdoc(doc, event.callback_invoker)
#     420 def invoke_callbacks() -> None:
#     421     for cb in self.change_callbacks():
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/document/callbacks.py:453, in invoke_with_curdoc(doc, f)
#     450 curdoc: Document|UnlockedDocumentProxy = UnlockedDocumentProxy(doc) if getattr(f, "nolock", False) else doc
#     452 with patch_curdoc(curdoc):
# --> 453     return f()
#
# File /opt/conda/lib/python3.11/site-packages/bokeh/util/callback_manager.py:183, in PropertyCallbackManager.trigger.<locals>.invoke()
#     181 if callbacks:
#     182     for callback in callbacks:
# --> 183         callback(attr, old, new)
#
# File /opt/conda/lib/python3.11/site-packages/panel/reactive.py:599, in Syncable._server_change(self, doc, ref, subpath, attr, old, new)
#     597     self._change_event(doc)
#     598 except Exception as e:
# --> 599     state._handle_exception(e)
#
# File /opt/conda/lib/python3.11/site-packages/panel/io/state.py:468, in _state._handle_exception(self, exception)
#     466     config.exception_handler(exception)
#     467 elif isinstance(exception, BaseException):
# --> 468     raise exception
#     469 else:
#     470     self.log(f'Exception of unknown type raised: {exception}', level='error')
#
# File /opt/conda/lib/python3.11/site-packages/panel/reactive.py:597, in Syncable._server_change(self, doc, ref, subpath, attr, old, new)
#     595 else:
#     596     try:
# --> 597         self._change_event(doc)
#     598     except Exception as e:
#     599         state._handle_exception(e)
#
# File /opt/conda/lib/python3.11/site-packages/panel/reactive.py:525, in Syncable._change_event(self, doc)
#     523 self._events = {}
#     524 with set_curdoc(doc):
# --> 525     self._process_events(events)
#
# File /opt/conda/lib/python3.11/site-packages/panel/widgets/slider.py:109, in _SliderBase._process_events(self, events)
#     107 if config.throttled:
#     108     events.pop("value", None)
# --> 109 super()._process_events(events)
#
# File /opt/conda/lib/python3.11/site-packages/panel/reactive.py:462, in Syncable._process_events(self, events)
#     460     self_params = {k: v for k, v in params.items() if '.' not in k}
#     461     with _syncing(self, list(self_params)):
# --> 462         self.param.update(**self_params)
#     463 for k, v in params.items():
#     464     if '.' not in k:
#
# File /opt/conda/lib/python3.11/site-packages/param/parameterized.py:2319, in Parameters.update(self_, arg, **kwargs)
#    2317         elif pname in private.async_refs:
#    2318             refs[pname] = private.async_refs[pname]
# -> 2319 restore = dict(self_._update(arg, **kwargs))
#    2320 return _ParametersRestorer(parameters=self_, restore=restore, refs=refs)
#
# File /opt/conda/lib/python3.11/site-packages/param/parameterized.py:2352, in Parameters._update(self_, arg, **kwargs)
#    2350 self_._BATCH_WATCH = BATCH_WATCH
#    2351 if not BATCH_WATCH:
# -> 2352     self_._batch_call_watchers()
#    2354 for tp in trigger_params:
#    2355     p = self_[tp]
#
# File /opt/conda/lib/python3.11/site-packages/param/parameterized.py:2546, in Parameters._batch_call_watchers(self_)
#    2541 events = [self_._update_event_type(watcher, event_dict[(name, watcher.what)],
#    2542                                    self_._TRIGGER)
#    2543           for name in watcher.parameter_names
#    2544           if (name, watcher.what) in event_dict]
#    2545 with _batch_call_watchers(self_.self_or_cls, enable=watcher.queued, run=False):
# -> 2546     self_._execute_watcher(watcher, events)
#
# File /opt/conda/lib/python3.11/site-packages/param/parameterized.py:2506, in Parameters._execute_watcher(self, watcher, events)
#    2504 else:
#    2505     try:
# -> 2506         watcher.fn(*args, **kwargs)
#    2507     except Skip:
#    2508         pass
#
# File /opt/conda/lib/python3.11/site-packages/panel/widgets/slider.py:509, in DiscreteSlider._sync_value(self, event)
#     507     self._syncing = True
#     508     with param.edit_constant(self):
# --> 509         setattr(self, event.name, self.values[event.new])
#     510 finally:
#     511     self._syncing = False
#
# File /opt/conda/lib/python3.11/site-packages/param/parameterized.py:528, in instance_descriptor.<locals>._f(self, obj, val)
#     526         instance_param = _instantiated_parameter(obj, self)
#     527     if instance_param is not None and self is not instance_param:
# --> 528         instance_param.__set__(obj, val)
#     529         return
#     530 return f(self, obj, val)
#
# File /opt/conda/lib/python3.11/site-packages/param/parameterized.py:530, in instance_descriptor.<locals>._f(self, obj, val)
#     528         instance_param.__set__(obj, val)
#     529         return
# --> 530 return f(self, obj, val)
#
# File /opt/conda/lib/python3.11/site-packages/param/parameterized.py:1553, in Parameter.__set__(self, obj, val)
#    1551 # Copy watchers here since they may be modified inplace during iteration
#    1552 for watcher in sorted(watchers, key=lambda w: w.precedence):
# -> 1553     obj.param._call_watcher(watcher, event)
#    1554 if not obj.param._BATCH_WATCH:
#    1555     obj.param._batch_call_watchers()
#
# File /opt/conda/lib/python3.11/site-packages/param/parameterized.py:2526, in Parameters._call_watcher(self_, watcher, event)
#    2524 event = self_._update_event_type(watcher, event, self_._TRIGGER)
#    2525 with _batch_call_watchers(self_.self_or_cls, enable=watcher.queued, run=False):
# -> 2526     self_._execute_watcher(watcher, (event,))
#
# File /opt/conda/lib/python3.11/site-packages/param/parameterized.py:2506, in Parameters._execute_watcher(self, watcher, events)
#    2504 else:
#    2505     try:
# -> 2506         watcher.fn(*args, **kwargs)
#    2507     except Skip:
#    2508         pass
#
# File /opt/conda/lib/python3.11/site-packages/panel/pane/holoviews.py:350, in HoloViews._widget_callback(self, event)
#     348 def _widget_callback(self, event):
#     349     for _, (plot, pane) in self._plots.items():
# --> 350         self._update_plot(plot, pane)
#
# File /opt/conda/lib/python3.11/site-packages/panel/pane/holoviews.py:332, in HoloViews._update_plot(self, plot, pane)
#     330 if plot.comm or state._unblocked(plot.document):
#     331     with unlocked():
# --> 332         plot.update(key)
#     333     if plot.comm and 'embedded' not in plot.root.tags:
#     334         plot.push()
#
# File /opt/conda/lib/python3.11/site-packages/holoviews/plotting/plot.py:957, in DimensionedPlot.update(self, key)
#     955 if len(self) == 1 and key in (0, self.keys[0]) and not self.drawn:
#     956     return self.initialize_plot()
# --> 957 item = self.__getitem__(key)
#     958 self.traverse(lambda x: setattr(x, '_updated', True))
#     959 return item
#
# File /opt/conda/lib/python3.11/site-packages/holoviews/plotting/plot.py:444, in DimensionedPlot.__getitem__(self, frame)
#     442 if not isinstance(frame, tuple):
#     443     frame = self.keys[frame]
# --> 444 self.update_frame(frame)
#     445 return self.state
#
# File /opt/conda/lib/python3.11/site-packages/geoviews/plotting/bokeh/plot.py:128, in GeoPlot.update_frame(self, key, ranges, element)
#     126 if element is not None:
#     127     self._set_unwrap_lons(element)
# --> 128 super().update_frame(key, ranges=ranges, element=element)
#
# File /opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/util.py:868, in hold_render.<locals>.wrapper(self, *args, **kwargs)
#     866 self.state.hold_render = True
#     867 try:
# --> 868     return f(self, *args, **kwargs)
#     869 finally:
#     870     self.state.hold_render = hold
#
# File /opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py:3462, in OverlayPlot.update_frame(self, key, ranges, element)
#    3459         if (triggering and all(s not in triggering for s in subplot.streams) and
#    3460             subplot not in self.dynamic_subplots):
#    3461             continue
# -> 3462     subplot.update_frame(key, ranges, element=el)
#    3464 if not self.batched and isinstance(self.hmap, DynamicMap) and items:
#    3465     init_kwargs = {'plots': self.handles['plots']}
#
# File /opt/conda/lib/python3.11/site-packages/geoviews/plotting/bokeh/plot.py:128, in GeoPlot.update_frame(self, key, ranges, element)
#     126 if element is not None:
#     127     self._set_unwrap_lons(element)
# --> 128 super().update_frame(key, ranges=ranges, element=element)
#
# File /opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/util.py:868, in hold_render.<locals>.wrapper(self, *args, **kwargs)
#     866 self.state.hold_render = True
#     867 try:
# --> 868     return f(self, *args, **kwargs)
#     869 finally:
#     870     self.state.hold_render = hold
#
# File /opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py:2306, in ElementPlot.update_frame(self, key, ranges, plot, element)
#    2303 if self.apply_hard_bounds:
#    2304     self._apply_hard_bounds(element, ranges)
# -> 2306 self._update_glyphs(element, ranges, self.style[self.cyclic_index])
#    2307 self._execute_hooks(element)
#
# File /opt/conda/lib/python3.11/site-packages/holoviews/plotting/bokeh/element.py:2221, in ElementPlot._update_glyphs(self, element, ranges, style)
#    2219     if 'visible' in style and hasattr(renderer, 'visible'):
#    2220         renderer.visible = style['visible']
# -> 2221     with abbreviated_exception():
#    2222         self._update_glyph(renderer, properties, mapping, glyph, source, data)
#    2223 elif not self.static_source:
#
# File /opt/conda/lib/python3.11/site-packages/holoviews/core/options.py:222, in abbreviated_exception.__exit__(self, etype, value, traceback)
#     220 def __exit__(self, etype, value, traceback):
#     221     if isinstance(value, Exception):
# --> 222         raise AbbreviatedException(etype, value, traceback)
#
# AbbreviatedException: ValueError: failed to validate MultiPolygons(id='p1110', ...).fill_color: expected an element of either String, Nullable(Color), Instance(Value), Instance(Field), Instance(Expr), Struct(value=Nullable(Color), transform=Instance(Transform)), Struct(field=String, transform=Instance(Transform)) or Struct(expr=Instance(Expression), transform=Instance(Transform)), got dim('norm_occurrences')
#
# To view the original traceback, catch this exception and call print_traceback() method.

# %%
gaviapac_ecoreg_gdf.to_csv('gavia_pacifica_ecoreg_gdf.csv')
